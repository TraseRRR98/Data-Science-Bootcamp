# %% [markdown]
# <a href="https://colab.research.google.com/github/TraseRRR98/NYC-Taxi-Analysis-Lab/blob/main/recycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt

# %%
recycle = pd.read_csv("/content/Recycling_Diversion_and_Capture_Rates_20240614.csv")

# %%
recycle.head()
# Out:
#              Zone District  Fiscal Month Number  Fiscal Year Month Name  \
# 0  Brooklyn North    BKN01                   10         2019      April
# 1  Brooklyn North    BKN02                   10         2019      April
# 2  Brooklyn North    BKN03                   10         2019      April
# 3  Brooklyn North    BKN04                   10         2019      April
# 4  Brooklyn North    BKN05                   10         2019      April
#
#    Diversion Rate-Total (Total Recycling / Total Waste)  \
# 0                                               14.7
# 1                                               20.0
# 2                                               12.2
# 3                                               15.5
# 4                                               10.1
#
#    Capture Rate-Paper (Total Paper / Max Paper)  \
# 0                                          44.9
# 1                                          34.2
# 2                                          33.5
# 3                                          35.2
# 4                                          22.3
#
#    Capture Rate-MGP (Total MGP / Max MGP)  \
# 0                                    43.0
# 1                                    57.9
# 2                                    44.9
# 3                                    68.5
# 4                                    45.1
#
#    Capture Rate-Total ((Total Recycling - Leaves (Recycling)) / (Max Paper + Max MGP))x100
# 0                                               44.1
# 1                                               41.2
# 2                                               38.2
# 3                                               48.8
# 4                                               31.5

# %%
def col_formatter(x):
  xs = re.split(r"\({1,2}", x)[0].lower().strip()
  xs = re.sub("\s|-", "_", xs)
  return xs

recycle.columns = [col_formatter(c) for c in recycle.columns]

# %%
recycle.describe(include="all")
# Out:
#          zone district  fiscal_month_number  fiscal_year month_name  \
# count    2832     2832          2832.000000  2832.000000       2832
# unique      7       59                  NaN          NaN         12
# top     Bronx    BKN01                  NaN          NaN      April
# freq      576       48                  NaN          NaN        236
# mean      NaN      NaN             6.500000  2017.500000        NaN
# std       NaN      NaN             3.452662     1.118231        NaN
# min       NaN      NaN             1.000000  2016.000000        NaN
# 25%       NaN      NaN             3.750000  2016.750000        NaN
# 50%       NaN      NaN             6.500000  2017.500000        NaN
# 75%       NaN      NaN             9.250000  2018.250000        NaN
# max       NaN      NaN            12.000000  2019.000000        NaN
#
#         diversion_rate_total  capture_rate_paper  capture_rate_mgp  \
# count            2832.000000         2832.000000       2832.000000
# unique                   NaN                 NaN               NaN
# top                      NaN                 NaN               NaN
# freq                     NaN                 NaN               NaN
# mean               17.483792           38.430191         61.224223
# std                 5.264288            9.013759         16.283391
# min                 5.900000           16.900000         20.400000
# 25%                13.800000           31.900000         48.400000
# 50%                16.900000           37.750000         61.600000
# 75%                21.000000           45.200000         74.425000
# max                33.800000           72.600000        101.800000
#
#         capture_rate_total
# count          2832.000000
# unique                 NaN
# top                    NaN
# freq                   NaN
# mean             46.157345
# std               9.496978
# min              18.500000
# 25%              39.700000
# 50%              46.300000
# 75%              52.625000
# max              75.500000

# %%
def date_formatter(yr, mo):
  d = dt.datetime.strptime(f"{yr}-{mo}", "%Y-%B").date()
  return d

# %%
recycle["date"] = recycle.apply(lambda df: date_formatter(df.fiscal_year, df.month_name), axis=1)

recycle["calendar_month"] = recycle.date.apply(lambda x: x.month)

# %%
recycle.head()
# Out:
#              zone district  fiscal_month_number  fiscal_year month_name  \
# 0  Brooklyn North    BKN01                   10         2019      April
# 1  Brooklyn North    BKN02                   10         2019      April
# 2  Brooklyn North    BKN03                   10         2019      April
# 3  Brooklyn North    BKN04                   10         2019      April
# 4  Brooklyn North    BKN05                   10         2019      April
#
#    diversion_rate_total  capture_rate_paper  capture_rate_mgp  \
# 0                  14.7                44.9              43.0
# 1                  20.0                34.2              57.9
# 2                  12.2                33.5              44.9
# 3                  15.5                35.2              68.5
# 4                  10.1                22.3              45.1
#
#    capture_rate_total        date  calendar_month
# 0                44.1  2019-04-01               4
# 1                41.2  2019-04-01               4
# 2                38.2  2019-04-01               4
# 3                48.8  2019-04-01               4
# 4                31.5  2019-04-01               4

# %%
rzm = (recycle
       .groupby(["zone", "month_name", "calendar_month"])["diversion_rate_total"]
       .mean()
       .reset_index()
       .sort_values(["zone", "calendar_month"]))

# %%
rzm.head()
# Out:
#     zone month_name  calendar_month  diversion_rate_total
# 4  Bronx    January               1             14.304167
# 3  Bronx   February               2             13.847917
# 7  Bronx      March               3             13.583333
# 0  Bronx      April               4             13.658333
# 8  Bronx        May               5             13.425000

# %%
def month_name(x):
  return dt.date(2020, x, 1).strftime("%B")

# %%
df = rzm.pivot(index="zone", columns=["calendar_month"], values="diversion_rate_total")

sns.heatmap(df, xticklabels=[month_name(c) for c in df.columns.to_list()], cmap="Greens")
# Out:
# <Axes: xlabel='calendar_month', ylabel='zone'>

# %%
sns.lineplot(rzm, x="calendar_month", y="diversion_rate_total", hue="zone")
# Out:
# <Axes: xlabel='calendar_month', ylabel='diversion_rate_total'>

# %%
g = sns.FacetGrid(recycle, col="zone", col_wrap=3)
g.map_dataframe(sns.histplot, x="capture_rate_paper")

for ax in g.axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# sns.histplot(recycle, x="capture_rate_paper", hue="zone")
# Out:
# <ipython-input-29-2f2b72ae33da>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
rzm = (recycle
       .groupby(["fiscal_year", "zone"])["diversion_rate_total"]
       .mean()
       .reset_index()
       .sort_values(["fiscal_year", "zone"]))

# %%
sns.lineplot(rzm, x="fiscal_year", y="diversion_rate_total", hue="zone")
# Out:
# <Axes: xlabel='fiscal_year', ylabel='diversion_rate_total'>

# %% [markdown]
# **Assignment:**
#
# 1. Make a lineplot of mean capture_rate_paper from 2016-2019 grouped by zone and fiscal_year
# 2. What district had the highest average diversion_rate_total in each fiscal_year?
# 3. What district had the lowest average diversion_rate_total in each fiscal_year?
# 4. Make a barplot of annual mean capture_rate_paper for Brooklyn South and Brooklyn North combined into one "Brooklyn"
# 5. Extra credit: make a plot of your choice

# %%
filteredData = recycle[(recycle["fiscal_year"] >= 2016) & (recycle["fiscal_year"] <= 2019)]

# %%
groupedData = filteredData.groupby(["zone", "fiscal_year"])["capture_rate_paper"].mean().reset_index()

# %%
sns.lineplot(data=groupedData, x="fiscal_year", y="capture_rate_paper", hue="zone")

plt.title("Mean Capture Rate Paper from 2016-2019 by Zone and Fiscal Year")
# Out:
# Text(0.5, 1.0, 'Mean Capture Rate Paper from 2016-2019 by Zone and Fiscal Year')

# %%
groupedDiversion = recycle.groupby(["fiscal_year", "zone"])["diversion_rate_total"].mean().reset_index()

# %%
highestDiversion = groupedDiversion.loc[groupedDiversion.groupby("fiscal_year")["diversion_rate_total"].idxmax()]
highestDiversion
# Out:
#     fiscal_year           zone  diversion_rate_total
# 3          2016      Manhattan             20.047917
# 10         2017      Manhattan             20.431250
# 20         2018  Staten Island             20.591667
# 24         2019      Manhattan             21.029861

# %%
lowestDiversion = groupedDiversion.loc[groupedDiversion.groupby("fiscal_year")["diversion_rate_total"].idxmin()]
lowestDiversion
# Out:
#     fiscal_year            zone  diversion_rate_total
# 1          2016  Brooklyn North             12.787037
# 7          2017           Bronx             13.192361
# 15         2018  Brooklyn North             13.986111
# 21         2019           Bronx             14.404861

# %%
recycle["zone"] = recycle["zone"].replace({"Brooklyn South": "Brooklyn", "Brooklyn North": "Brooklyn"})

# %%
brooklynData = recycle[recycle["zone"] == "Brooklyn"].groupby(["fiscal_year"])["capture_rate_paper"].mean().reset_index()

# %%
sns.barplot(data=brooklynData, x="fiscal_year", y="capture_rate_paper")
plt.title("Annual Mean Capture Rate Paper for Brooklyn")
# Out:
# Text(0.5, 1.0, 'Annual Mean Capture Rate Paper for Brooklyn')

# %%
plt.figure(figsize=(10, 6))
sns.jointplot(data=recycle, x="capture_rate_total", y="diversion_rate_total", kind="scatter", hue="zone", palette="viridis")
plt.suptitle("Joint Plot of Capture Rate Total and Diversion Rate Total by Zone", y=1.02)
# Out:
# Text(0.5, 1.02, 'Joint Plot of Capture Rate Total and Diversion Rate Total by Zone')
